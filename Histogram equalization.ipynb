# %% [markdown]
# # Histogram Equilization

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt

# %%
path = './image.jpg'
img = cv2.imread(path)
plt.imshow(img)

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])
plt.plot(hist.cumsum(),'r')

# %%
plt.hist(img.flatten(),256,[0,256], color = 'r')
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized,'b')
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
equ = cv2.equalizeHist(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-2e322eccd89d> in <module>
# ----> 1 equ = cv2.equalizeHist(img)
#
# error: OpenCV(4.5.1) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-kh7iq4w7\opencv\modules\imgproc\src\histogram.cpp:3439: error: (-215:Assertion failed) _src.type() == CV_8UC1 in function 'cv::equalizeHist'
